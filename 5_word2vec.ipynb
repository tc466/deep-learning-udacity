# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /scrap/tc466/deep-learning-udacity/tensorflow/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # sliding window
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.296454
# Nearest to up: tombs, constipation, anus, chaitin, zanu, austere, haj, somali,
# Nearest to by: telemann, duplex, xk, landscapes, dispersing, veronica, pfeiffer, preservatives,
# Nearest to first: gorgon, precession, developing, ganz, player, domine, ally, essentially,
# Nearest to from: least, quranic, jerk, antiquities, degrade, aficionados, pisa, thea,
# Nearest to no: sticking, kinnock, formants, esdras, scudetto, autopilot, tillich, devi,
# Nearest to one: backside, westland, drum, plotting, futurians, lempira, overheating, linda,
# Nearest to the: usc, jobs, stevenson, ltc, psa, replicants, tetrahedron, triassic,
# Nearest to seven: mutation, inlet, preludes, lea, baudot, jake, lobby, maimonides,
# Nearest to he: reptiles, agha, regimen, companionship, eigenvalue, phenotypes, ingalls, danneskj,
# Nearest to world: optical, carbohydrates, federations, timers, hartree, apprehension, bricklin, decapitate,
# Nearest to it: answering, songbook, vulcan, dusseldorf, donkeys, peugeot, uniquely, attempting,
# Nearest to with: parables, lye, fungi, nye, inhabitant, which, victims, generalized,
# Nearest to most: flooded, dub, raccoons, factum, penicillium, garand, squandered, interacted,
# Nearest to that: neighborhoods, warcraft, corinthian, rook, transsexual, govern, breisgau, willie,
# Nearest to an: zoroastrian, wade, admitting, issued, tus, beverages, invalid, appointees,
# Nearest to five: draining, radiate, configured, shocking, scholarships, poppy, replicator, anchors,
# Average loss at step 2000: 4.366115
# Average loss at step 4000: 3.868964
# Average loss at step 6000: 3.789365
# Average loss at step 8000: 3.691318
# Average loss at step 10000: 3.616852
# Nearest to up: anus, explicit, crtc, spectroscopy, discover, zanu, austere, tombs,
# Nearest to by: was, artisan, with, been, while, dont, on, in,
# Nearest to first: precession, ubiquitous, sand, bother, through, at, avl, developing,
# Nearest to from: in, into, with, at, through, on, balaenoptera, aficionados,
# Nearest to no: it, kantian, devi, secures, bomarc, he, primaries, hamar,
# Nearest to one: two, three, six, seven, eight, four, intercepted, five,
# Nearest to the: its, his, a, this, their, ecclesia, an, seabed,
# Nearest to seven: eight, six, nine, five, four, zero, three, two,
# Nearest to he: it, they, she, who, we, there, and, still,
# Nearest to world: optical, carbohydrates, unmanned, spook, timers, countermeasure, apprehension, premierships,
# Nearest to it: he, this, there, not, they, no, which, terminates,
# Nearest to with: in, for, hume, surfaced, generalized, on, from, parables,
# Nearest to most: poetess, wen, bourgeois, flooded, dub, sandwich, interacted, penicillium,
# Nearest to that: which, rook, it, cockpits, but, what, resurgence, warcraft,
# Nearest to an: the, issued, ballad, infielder, dcs, vogt, xun, ef,
# Nearest to five: eight, six, four, seven, three, nine, zero, two,
# Average loss at step 12000: 3.597466
# Average loss at step 14000: 3.571539
# Average loss at step 16000: 3.409203
# Average loss at step 18000: 3.457039
# Average loss at step 20000: 3.546013
# Nearest to up: anus, richest, explicit, greenaway, receptors, holmes, him, typically,
# Nearest to by: be, against, with, in, for, were, was, into,
# Nearest to first: last, firewall, precession, sand, ubiquitous, avl, neglected, same,
# Nearest to from: into, in, through, at, prions, with, and, during,
# Nearest to no: it, devi, alistair, itinerant, shirley, kantian, fines, pompey,
# Nearest to one: four, two, three, eight, six, seven, five, nine,
# Nearest to the: its, their, his, this, a, rumi, newborn, archived,
# Nearest to seven: six, eight, nine, five, three, four, zero, two,
# Nearest to he: it, she, they, who, there, actually, never, git,
# Nearest to world: optical, spook, middle, countermeasure, unmanned, cores, carbohydrates, status,
# Nearest to it: he, there, this, they, which, not, only, often,
# Nearest to with: between, in, by, for, generalized, queene, from, into,
# Nearest to most: many, some, more, wen, malfunction, sasl, southern, larissa,
# Nearest to that: which, but, what, this, retribution, however, cheung, if,
# Nearest to an: dissociated, crushed, vogt, the, signifying, modafinil, revolvers, dcs,
# Nearest to five: four, six, seven, eight, three, two, zero, nine,
# Average loss at step 22000: 3.507421
# Average loss at step 24000: 3.487401
# Average loss at step 26000: 3.481398
# Average loss at step 28000: 3.483958
# Average loss at step 30000: 3.501641
# Nearest to up: anus, them, him, richest, explicit, receptors, maximus, positions,
# Nearest to by: in, with, under, duplex, were, against, from, was,
# Nearest to first: last, second, firewall, same, ubiquitous, best, quanta, claudian,
# Nearest to from: into, during, in, through, after, of, under, including,
# Nearest to no: any, a, it, not, pompey, there, kantian, lining,
# Nearest to one: two, four, seven, six, five, eight, three, nine,
# Nearest to the: their, its, his, some, a, many, repeal, wyndham,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to he: she, it, they, who, there, never, actually, later,
# Nearest to world: optical, spook, thiele, carbohydrates, karma, status, cores, timers,
# Nearest to it: he, there, this, they, she, also, usually, not,
# Nearest to with: between, in, hume, by, for, into, outcry, under,
# Nearest to most: more, many, some, sandwich, yielding, larissa, imi, falsity,
# Nearest to that: which, but, this, what, if, however, when, steals,
# Nearest to an: crushed, dissociated, treasured, vogt, martina, ef, beverages, darren,
# Nearest to five: four, eight, seven, six, three, zero, nine, two,
# Average loss at step 32000: 3.501701
# Average loss at step 34000: 3.495980
# Average loss at step 36000: 3.457573
# Average loss at step 38000: 3.300427
# Average loss at step 40000: 3.429292
# Nearest to up: anus, them, him, out, down, somali, compress, richest,
# Nearest to by: as, be, with, when, provability, was, fared, obsessive,
# Nearest to first: last, second, claudian, firewall, quanta, opposing, best, estrogen,
# Nearest to from: through, into, in, dug, for, decentralization, including, on,
# Nearest to no: any, or, pompey, there, kantian, lining, every, disgrace,
# Nearest to one: seven, two, eight, six, four, five, nine, three,
# Nearest to the: its, their, a, this, any, each, his, islets,
# Nearest to seven: eight, five, nine, six, four, three, zero, two,
# Nearest to he: she, it, they, there, who, git, never, i,
# Nearest to world: optical, bricklin, spook, timers, year, mainframe, top, mfm,
# Nearest to it: he, there, this, she, they, which, usually, we,
# Nearest to with: between, when, in, by, molecular, hume, generalized, outcry,
# Nearest to most: more, many, some, roping, backgammon, larissa, falsity, wen,
# Nearest to that: which, what, this, however, where, if, because, when,
# Nearest to an: crushed, sunni, mountaineers, appointees, vogt, transliteration, darren, dissociated,
# Nearest to five: seven, six, four, eight, three, nine, two, zero,
# Average loss at step 42000: 3.442807
# Average loss at step 44000: 3.453684
# Average loss at step 46000: 3.455696
# Average loss at step 48000: 3.362009
# Average loss at step 50000: 3.381072
# Nearest to up: out, them, anus, him, down, compress, shooters, back,
# Nearest to by: was, through, marconi, against, shalmaneser, during, with, under,
# Nearest to first: last, second, next, claudian, austronesian, firewall, classic, previous,
# Nearest to from: through, during, into, in, at, on, and, winnie,
# Nearest to no: any, always, padded, than, kantian, lifton, another, eudoxia,
# Nearest to one: six, two, eight, seven, four, three, nine, five,
# Nearest to the: its, their, his, this, a, echidna, some, provocation,
# Nearest to seven: eight, six, three, nine, five, four, zero, two,
# Nearest to he: she, it, they, there, who, we, never, then,
# Nearest to world: bricklin, rico, spook, optical, community, year, timers, bah,
# Nearest to it: he, there, she, this, they, then, now, often,
# Nearest to with: between, molecular, against, grassroots, absalon, by, purebred, when,
# Nearest to most: more, many, some, roping, among, backgammon, blasting, imi,
# Nearest to that: which, however, what, where, but, because, steals, this,
# Nearest to an: dissociated, crushed, mountaineers, sunni, vogt, the, mcgraw, transliteration,
# Nearest to five: four, six, seven, eight, three, two, zero, nine,
# Average loss at step 52000: 3.436297
# Average loss at step 54000: 3.428081
# Average loss at step 56000: 3.437422
# Average loss at step 58000: 3.398033
# Average loss at step 60000: 3.394024
# Nearest to up: out, them, off, anus, him, down, compress, back,
# Nearest to by: shalmaneser, timesharing, under, unresolved, be, against, through, including,
# Nearest to first: second, last, claudian, next, classic, quanta, firewall, third,
# Nearest to from: through, into, including, winnie, on, sharply, dug, wushu,
# Nearest to no: any, kantian, padded, automatically, dealing, cumont, little, only,
# Nearest to one: two, four, six, seven, eight, three, five, nine,
# Nearest to the: their, its, a, this, some, hopf, his, nano,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to he: she, it, they, there, who, never, we, later,
# Nearest to world: bricklin, rico, spook, year, optical, community, thiele, bah,
# Nearest to it: he, there, this, she, they, often, now, we,
# Nearest to with: between, including, molecular, ventricle, under, ahaziah, involves, ravine,
# Nearest to most: many, more, some, roping, among, use, backgammon, earliest,
# Nearest to that: which, what, this, however, it, where, kurgan, steals,
# Nearest to an: crushed, appointees, sunni, dissociated, mountaineers, intelsat, ef, beverages,
# Nearest to five: six, four, eight, seven, three, zero, nine, two,
# Average loss at step 62000: 3.242482
# Average loss at step 64000: 3.255276
# Average loss at step 66000: 3.410001
# Average loss at step 68000: 3.392193
# Average loss at step 70000: 3.360453
# Nearest to up: them, out, off, down, him, back, anus, compress,
# Nearest to by: through, duplex, be, huntley, using, dozen, in, unresolved,
# Nearest to first: second, last, claudian, best, next, third, firewall, final,
# Nearest to from: through, into, between, in, during, balaenoptera, dug, for,
# Nearest to no: any, automatically, kantian, little, than, gathers, or, padded,
# Nearest to one: two, seven, six, four, eight, five, three, nine,
# Nearest to the: its, their, a, any, this, these, each, some,
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to he: she, it, they, there, who, we, never, later,
# Nearest to world: bricklin, spook, year, mainframe, rico, cold, bah, timers,
# Nearest to it: he, there, she, this, they, then, still, often,
# Nearest to with: between, iho, involves, queene, ventricle, molecular, within, into,
# Nearest to most: more, many, roping, some, less, use, corona, among,
# Nearest to that: which, what, however, this, but, encompasses, crass, also,
# Nearest to an: mountaineers, sunni, crushed, contribute, irreconcilable, renouncing, appointees, mcgraw,
# Nearest to five: four, six, seven, three, eight, nine, zero, two,
# Average loss at step 72000: 3.378282
# Average loss at step 74000: 3.351004
# Average loss at step 76000: 3.325394
# Average loss at step 78000: 3.355807
# Average loss at step 80000: 3.380512
# Nearest to up: out, off, them, him, down, anus, back, compress,
# Nearest to by: from, shalmaneser, through, encyclopaedia, dont, and, duplex, in,
# Nearest to first: second, last, third, next, firewall, final, best, claudian,
# Nearest to from: through, into, by, diablo, in, dug, quranic, winnie,
# Nearest to no: any, little, pompey, than, padded, automatically, shirley, lifton,
# Nearest to one: seven, two, six, eight, three, four, five, nine,
# Nearest to the: its, their, this, his, rumi, a, our, appia,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to he: she, it, they, there, who, we, later, never,
# Nearest to world: bricklin, cold, spook, timers, bah, rico, panoramas, thiele,
# Nearest to it: he, she, there, this, they, itself, wiccans, we,
# Nearest to with: between, queene, iho, seceded, ventricle, generalized, electrolyte, besides,
# Nearest to most: many, more, some, roping, less, among, mesh, especially,
# Nearest to that: which, however, steals, where, beatty, what, expose, but,
# Nearest to an: crushed, mountaineers, renouncing, appointees, dissociated, irreconcilable, gravel, sunni,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Average loss at step 82000: 3.407376
# Average loss at step 84000: 3.414484
# Average loss at step 86000: 3.390338
# Average loss at step 88000: 3.351893
# Average loss at step 90000: 3.363476
# Nearest to up: out, off, them, him, down, back, anus, compress,
# Nearest to by: with, timesharing, through, against, without, when, heterogeneous, technicolor,
# Nearest to first: second, last, claudian, next, best, final, guderian, original,
# Nearest to from: through, into, during, in, decentralization, between, hardliners, terran,
# Nearest to no: any, little, only, gathers, than, revealed, carcinogens, padded,
# Nearest to one: seven, two, four, eight, six, three, five, th,
# Nearest to the: its, this, his, their, any, a, wolof, each,
# Nearest to seven: eight, five, four, six, nine, three, zero, one,
# Nearest to he: she, they, it, there, who, originally, but, we,
# Nearest to world: bricklin, thiele, spook, timers, rico, cold, sigma, counterintelligence,
# Nearest to it: he, she, there, this, they, itself, often, usually,
# Nearest to with: between, in, nailed, involves, by, ventricle, surfaced, queene,
# Nearest to most: many, more, some, less, roping, several, among, use,
# Nearest to that: which, however, what, but, crass, miscegenation, because, steals,
# Nearest to an: another, beverages, crushed, mountaineers, partials, appointees, dodgson, vogt,
# Nearest to five: seven, eight, four, six, three, nine, zero, two,
# Average loss at step 92000: 3.399495
# Average loss at step 94000: 3.249176
# Average loss at step 96000: 3.361390
# Average loss at step 98000: 3.243631
# Average loss at step 100000: 3.355022
# Nearest to up: off, out, them, him, down, back, anus, me,
# Nearest to by: been, without, unresolved, when, using, through, from, technicolor,
# Nearest to first: second, last, next, best, third, final, claudian, firewall,
# Nearest to from: into, through, in, during, winnie, laes, unlike, christological,
# Nearest to no: any, little, only, gathers, dealing, padded, tierra, every,
# Nearest to one: two, seven, four, eight, five, three, six, nine,
# Nearest to the: its, their, his, a, her, your, hopf, each,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Nearest to he: she, it, they, there, who, we, never, this,
# Nearest to world: panoramas, timers, sigma, rico, year, bible, postulating, country,
# Nearest to it: he, she, this, there, they, never, often, itself,
# Nearest to with: between, ventricle, including, iho, coyne, into, when, in,
# Nearest to most: more, less, especially, some, among, many, particularly, use,
# Nearest to that: which, however, what, steals, who, crass, kurgan, but,
# Nearest to an: another, irreconcilable, mountaineers, crushed, beverages, appointees, dissociated, marathon,
# Nearest to five: seven, four, six, eight, three, two, zero, nine,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, 2 * bag_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  window = collections.deque(maxlen=span) # sliding window
  for _ in range(span):
    window.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = bag_window  # target label at the center of the window
    buffer = list(window)
    labels[i, 0] = buffer.pop(target)
    batch[i] = buffer
    window.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[x] for x in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed_sum = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), axis=1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed_sum,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.176062
# Nearest to their: oc, mathematische, intuitively, enforceable, tap, roasting, plebeian, wessex,
# Nearest to many: ritter, histidine, veritable, arnstadt, catatonic, guaranteed, excise, alger,
# Nearest to three: demands, syndromes, was, cursive, teleplay, flock, ere, compartment,
# Nearest to can: wend, furthering, pao, showcased, cue, ortelius, fledging, functional,
# Nearest to up: recognizable, iud, shalom, flores, auden, influenza, wadis, eagerly,
# Nearest to state: opposes, ragtime, suda, mahler, tuck, rom, clich, specialists,
# Nearest to may: terrific, braganza, heels, beard, reacts, pseudoscience, carrots, assam,
# Nearest to between: chatting, logistic, pretence, benson, vhdl, incentive, cancelled, cryptanalysis,
# Nearest to d: advertisement, violently, semmelweis, clin, woodcuts, distinct, masorti, elder,
# Nearest to and: tale, palatal, binary, duets, savings, putonghua, airframes, tacitus,
# Nearest to for: flemish, knockout, mcleod, roms, losers, mps, foresaw, quadra,
# Nearest to be: fps, ixian, harkonnen, dal, existence, tigris, welterweight, dominant,
# Nearest to history: yearwood, righteousness, ecowas, goa, immolation, economical, lys, atkinson,
# Nearest to such: sher, enlarging, monstrous, violent, heiden, caroli, amyraut, ueshiba,
# Nearest to states: paso, harden, lifted, namespaces, verizon, pierrot, hartford, plexus,
# Nearest to these: viii, carnatic, commuting, canonically, fethry, worldly, fisk, deserve,
# Average loss at step 2000: 4.572583
# Average loss at step 4000: 3.925453
# Average loss at step 6000: 3.724086
# Average loss at step 8000: 3.524658
# Average loss at step 10000: 3.474757
# Nearest to their: his, its, her, the, regenerative, any, our, biomechanics,
# Nearest to many: some, several, all, most, these, cn, histidine, umno,
# Nearest to three: seven, five, four, six, eight, zero, two, nine,
# Nearest to can: may, would, could, will, must, should, cannot, to,
# Nearest to up: denunciation, influenza, crowley, auden, bre, attempts, freeman, climates,
# Nearest to state: opposes, kabaddi, tuck, coder, germania, characterizes, bagpipe, majority,
# Nearest to may: can, would, could, will, must, should, might, to,
# Nearest to between: vhdl, teng, retrospect, arranges, binoculars, runic, wyche, tectonic,
# Nearest to d: b, serenity, elric, samuel, sophistication, labeling, ginger, meps,
# Nearest to and: or, alioth, rutland, courtship, suo, leonis, clarence, unbound,
# Nearest to for: of, with, luddites, bombers, soroban, mustafa, flaw, raphaelite,
# Nearest to be: refer, vater, bt, debauchery, katharine, have, him, legionnaires,
# Nearest to history: junction, draped, toms, titular, agouti, inevitable, napalm, amicus,
# Nearest to such: well, known, diophantus, aurelian, regarded, overviews, gnaeus, epithet,
# Nearest to states: kingdom, nineteenth, plexus, sail, pierrot, formosa, moqed, verbal,
# Nearest to these: all, other, some, many, naturalization, various, constituci, several,
# Average loss at step 12000: 3.500496
# Average loss at step 14000: 3.431235
# Average loss at step 16000: 3.433703
# Average loss at step 18000: 3.405634
# Average loss at step 20000: 3.219395
# Nearest to their: its, his, her, the, them, both, preserving, invisibly,
# Nearest to many: some, several, these, all, numerous, both, most, various,
# Nearest to three: four, two, five, six, seven, eight, nine, zero,
# Nearest to can: could, will, may, must, would, should, might, cannot,
# Nearest to up: crowley, out, down, climates, him, influenza, eventually, carmack,
# Nearest to state: government, nepos, conrad, ancestors, kabaddi, democratic, slack, sinless,
# Nearest to may: can, would, must, might, will, could, should, cannot,
# Nearest to between: teng, into, arranges, vhdl, among, noxious, over, with,
# Nearest to d: b, UNK, delivering, ranking, schr, elan, lobbyist, samuel,
# Nearest to and: while, or, although, dougherty, but, including, jackie, who,
# Nearest to for: bombers, rab, malik, after, maronite, turbulent, raping, garnered,
# Nearest to be: refer, being, produce, bundaberg, geckos, have, vater, welterweight,
# Nearest to history: radioactive, perpignan, junction, roddick, emir, museum, rhodesia, gangster,
# Nearest to such: well, known, diophantus, medica, these, epithet, sanger, regarded,
# Nearest to states: kingdom, nations, plexus, eurystheus, fencers, nineteenth, livelihood, dependence,
# Nearest to these: various, some, many, major, other, different, all, fairest,
# Average loss at step 22000: 3.363296
# Average loss at step 24000: 3.282791
# Average loss at step 26000: 3.254011
# Average loss at step 28000: 3.286349
# Average loss at step 30000: 3.228553
# Nearest to their: its, his, her, the, our, your, nnhilde, lukewarm,
# Nearest to many: several, some, various, all, numerous, both, these, most,
# Nearest to three: six, four, five, eight, seven, two, nine, zero,
# Nearest to can: will, could, may, must, would, should, might, cannot,
# Nearest to up: off, out, down, them, starboard, reconsidered, mardi, gourd,
# Nearest to state: brightest, government, fields, natufian, majority, ancestors, antiquaries, locusts,
# Nearest to may: can, must, could, would, will, might, should, does,
# Nearest to between: with, into, over, fulani, baile, from, through, teng,
# Nearest to d: h, b, assemble, ghc, thurber, premiered, j, coliseum,
# Nearest to and: or, but, although, including, while, with, in, frogs,
# Nearest to for: grammatical, while, pidgin, after, against, karen, gilbert, mustafa,
# Nearest to be: lead, refer, being, become, disintegrated, remain, move, take,
# Nearest to history: list, dribble, development, origin, economy, roddick, alves, studies,
# Nearest to such: well, follows, diophantus, sahrawi, ryan, many, medica, kittyhawk,
# Nearest to states: kingdom, nations, penetrates, identifier, dependence, discovered, eurystheus, impartial,
# Nearest to these: various, many, certain, other, some, different, several, they,
# Average loss at step 32000: 3.015195
# Average loss at step 34000: 3.205983
# Average loss at step 36000: 3.198836
# Average loss at step 38000: 3.154884
# Average loss at step 40000: 3.155488
# Nearest to their: its, his, her, our, your, the, whose, my,
# Nearest to many: some, several, various, numerous, all, most, both, few,
# Nearest to three: four, six, five, seven, eight, zero, two, nine,
# Nearest to can: could, may, will, might, should, would, must, cannot,
# Nearest to up: off, out, down, gluing, them, arranges, diacritic, printings,
# Nearest to state: longbowmen, coulomb, signing, stacy, louisville, tove, protege, uganda,
# Nearest to may: must, can, might, should, could, will, would, cannot,
# Nearest to between: within, among, teng, with, over, upanishads, in, into,
# Nearest to d: b, ghc, attractiveness, ach, v, immersive, coliseum, cooperative,
# Nearest to and: or, including, while, than, although, but, however, leonis,
# Nearest to for: against, mustafa, deployable, and, before, transitioning, during, without,
# Nearest to be: lead, being, produce, refer, remain, been, take, were,
# Nearest to history: list, hw, smelling, feyerabend, origin, roddick, study, angers,
# Nearest to such: well, follows, opposed, described, medica, result, far, known,
# Nearest to states: kingdom, nations, plexus, letters, postmaster, eurystheus, rayner, antipope,
# Nearest to these: various, several, those, different, other, capable, there, many,
# Average loss at step 42000: 3.203969
# Average loss at step 44000: 3.147596
# Average loss at step 46000: 3.142512
# Average loss at step 48000: 3.050035
# Average loss at step 50000: 3.061853
# Nearest to their: its, his, her, your, our, my, the, other,
# Nearest to many: some, several, numerous, various, all, most, thousands, certain,
# Nearest to three: four, five, seven, six, two, eight, zero, nine,
# Nearest to can: could, may, must, should, will, might, would, cannot,
# Nearest to up: off, down, back, out, him, them, retailer, gluing,
# Nearest to state: government, longbowmen, majority, despatch, signing, uganda, pitting, coulomb,
# Nearest to may: can, must, should, will, might, would, could, cannot,
# Nearest to between: within, with, upanishads, into, livonian, over, teng, cav,
# Nearest to d: b, seydlitz, bibliographic, dodgers, aia, unintentional, anarchistic, alms,
# Nearest to and: or, including, although, while, leonis, berkshire, malaysian, scaling,
# Nearest to for: cedric, including, dect, turbulent, mustafa, without, hizbullah, turntables,
# Nearest to be: being, refer, lead, produce, remain, contain, were, occur,
# Nearest to history: list, smelling, aspect, photography, sclc, because, oregon, enveloped,
# Nearest to such: well, follows, known, described, seen, far, regarded, opposed,
# Nearest to states: kingdom, nations, cdi, rayner, antipope, easiest, parts, molina,
# Nearest to these: various, several, other, many, some, infighting, all, certain,
# Average loss at step 52000: 3.095276
# Average loss at step 54000: 3.092393
# Average loss at step 56000: 2.925682
# Average loss at step 58000: 3.027043
# Average loss at step 60000: 3.050521
# Nearest to their: its, his, her, our, your, the, whose, my,
# Nearest to many: some, several, numerous, various, all, most, these, certain,
# Nearest to three: five, four, six, seven, eight, two, zero, nine,
# Nearest to can: may, could, might, will, must, should, cannot, would,
# Nearest to up: off, down, out, back, printings, aside, attempts, arranges,
# Nearest to state: government, subsumed, agent, bush, boston, domestic, differentiating, majority,
# Nearest to may: can, might, must, should, would, will, could, cannot,
# Nearest to between: with, upanishads, within, through, bayesian, ecu, in, livonian,
# Nearest to d: b, ig, semites, som, broom, miami, devries, russell,
# Nearest to and: or, but, although, including, while, leonis, though, than,
# Nearest to for: rab, after, voyaging, telco, heian, oxidising, without, hernandez,
# Nearest to be: remain, lead, being, refer, produce, exist, take, cause,
# Nearest to history: reign, concept, list, biography, draped, modern, nature, origins,
# Nearest to such: well, follows, seen, opposed, described, regarded, nndb, known,
# Nearest to states: kingdom, nations, parties, provinces, countries, aqaba, metalworking, parole,
# Nearest to these: several, various, different, many, other, certain, fairest, multiple,
# Average loss at step 62000: 3.014801
# Average loss at step 64000: 2.913854
# Average loss at step 66000: 2.929369
# Average loss at step 68000: 2.956676
# Average loss at step 70000: 3.004552
# Nearest to their: its, his, your, our, her, the, my, these,
# Nearest to many: several, some, numerous, various, all, most, those, both,
# Nearest to three: five, six, seven, two, four, zero, eight, bac,
# Nearest to can: could, may, cannot, will, might, must, should, would,
# Nearest to up: off, down, back, together, printings, substitute, out, arranges,
# Nearest to state: tide, toll, subsumed, differentiating, coulomb, government, longbowmen, pitting,
# Nearest to may: might, should, can, will, could, must, would, cannot,
# Nearest to between: with, among, within, upanishads, livonian, crevasses, into, teng,
# Nearest to d: b, reisman, devries, gepids, lz, hunyadi, steinbeck, semites,
# Nearest to and: or, but, including, leonis, while, which, planting, etc,
# Nearest to for: after, mustafa, reinvention, raphaelite, hernandez, meir, of, luddites,
# Nearest to be: remain, refer, being, produce, cause, lead, take, operate,
# Nearest to history: origins, development, concept, draped, smelling, study, myth, evolution,
# Nearest to such: well, follows, seen, opposed, described, known, result, referred,
# Nearest to states: kingdom, nations, cdi, autoroute, somme, provinces, metalworking, ial,
# Nearest to these: those, various, several, certain, many, their, some, other,
# Average loss at step 72000: 2.947396
# Average loss at step 74000: 2.864407
# Average loss at step 76000: 2.998200
# Average loss at step 78000: 3.006413
# Average loss at step 80000: 2.844399
# Nearest to their: its, her, his, your, our, my, the, certain,
# Nearest to many: some, several, numerous, various, all, most, certain, both,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to can: may, might, could, will, cannot, must, should, would,
# Nearest to up: off, down, out, back, aside, arranges, together, printings,
# Nearest to state: government, constitution, tide, states, despatch, territory, hata, parliament,
# Nearest to may: can, might, should, could, will, must, would, cannot,
# Nearest to between: with, upanishads, within, among, baen, bek, toxins, against,
# Nearest to d: b, h, steinbeck, cloud, genet, reisman, compositions, cx,
# Nearest to and: or, including, etc, while, spotless, though, although, but,
# Nearest to for: coax, quill, hernandez, kerberos, turntables, cedric, salk, mustafa,
# Nearest to be: remain, refer, produce, lead, being, represent, become, create,
# Nearest to history: list, webmineral, directory, consists, mario, origins, version, invasion,
# Nearest to such: well, follows, opposed, seen, described, referred, known, perceived,
# Nearest to states: nations, kingdom, provinces, countries, companies, chaffee, aqaba, state,
# Nearest to these: various, those, several, certain, other, boric, numerous, few,
# Average loss at step 82000: 2.941190
# Average loss at step 84000: 2.901904
# Average loss at step 86000: 2.917710
# Average loss at step 88000: 2.945928
# Average loss at step 90000: 2.829264
# Nearest to their: its, his, your, her, our, my, the, whose,
# Nearest to many: some, numerous, several, various, both, all, thousands, hundreds,
# Nearest to three: six, four, five, seven, two, eight, zero, chronica,
# Nearest to can: must, may, will, might, should, could, cannot, would,
# Nearest to up: off, down, out, back, arranges, aside, panned, angel,
# Nearest to state: government, reacts, bookseller, constitution, differentiating, salvadorans, laundering, parliament,
# Nearest to may: can, might, will, should, must, could, would, cannot,
# Nearest to between: with, upanishads, within, across, over, bayesian, among, into,
# Nearest to d: resettle, b, cloud, novas, studded, genet, detergents, pepe,
# Nearest to and: or, while, including, although, etc, leonis, but, prev,
# Nearest to for: after, of, turntables, mustafa, cedric, interferometer, kerberos, without,
# Nearest to be: remain, refer, represent, being, lead, operate, occur, take,
# Nearest to history: list, origins, map, timeline, journal, tradition, biography, bloomfield,
# Nearest to such: well, follows, seen, result, known, serve, opposed, far,
# Nearest to states: kingdom, nations, countries, cdi, chaffee, provinces, inescapable, state,
# Nearest to these: various, certain, multiple, those, several, different, microscopic, their,
# Average loss at step 92000: 2.895607
# Average loss at step 94000: 2.890514
# Average loss at step 96000: 2.714104
# Average loss at step 98000: 2.461079
# Average loss at step 100000: 2.713265
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to many: some, several, numerous, various, all, both, thousands, hundreds,
# Nearest to three: four, five, seven, six, eight, two, zero, nine,
# Nearest to can: must, might, could, cannot, should, will, may, would,
# Nearest to up: off, out, down, together, back, aside, noticing, panned,
# Nearest to state: government, manchester, southampton, harvard, states, supremacy, laundering, replicants,
# Nearest to may: might, should, must, can, could, will, would, cannot,
# Nearest to between: among, with, across, through, thus, within, upanishads, slr,
# Nearest to d: b, golfo, celeste, literals, euskara, adjectives, genet, nostra,
# Nearest to and: or, but, including, while, etc, however, although, leonis,
# Nearest to for: after, including, quill, whereby, inextricably, tenor, confidently, turntables,
# Nearest to be: remain, being, refer, occur, lead, serve, move, become,
# Nearest to history: list, culture, origins, origin, palestine, literature, india, empires,
# Nearest to such: well, follows, seen, far, result, opposed, viewed, referred,
# Nearest to states: kingdom, nations, countries, bolsheviks, jun, noord, assisi, provinces,
# Nearest to these: various, those, certain, multiple, several, numerous, other, different,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
