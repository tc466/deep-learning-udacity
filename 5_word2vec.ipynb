# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # sliding window
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.283986
# Nearest to an: druidry, grote, accrue, subgenres, marrow, kinshasa, jaeger, piloted,
# Nearest to some: anthropic, incipient, hype, reprise, alan, baud, lipid, abdu,
# Nearest to a: omar, fuck, avl, infirmities, countered, inline, tours, reminder,
# Nearest to see: judges, antebellum, ivb, strikes, seanad, objectivity, collins, idaho,
# Nearest to used: inalienable, pacemaker, conferencing, troubles, globalisation, calvi, increased, hippocrates,
# Nearest to were: caricatures, strengthen, alamein, sticker, hur, pollutant, disappearance, lydians,
# Nearest to is: crunch, abalone, cognitive, storage, huntingdon, sixteenth, nolo, replicating,
# Nearest to if: chaney, kolbin, bureau, ogden, torsional, rantissi, sobre, deanna,
# Nearest to history: braxton, unfamiliar, aesthetically, recognise, agamemnon, televangelist, manchu, accomplishments,
# Nearest to at: wire, rio, italia, marx, fretted, cipher, trisomy, blatant,
# Nearest to can: covens, contentious, invention, bre, viscous, joss, crs, chromite,
# Nearest to which: galloway, angrily, mysteries, capabilities, steamships, adversus, conscience, assets,
# Nearest to as: hemi, weekly, perplexed, tells, hayes, indie, commissioners, saga,
# Nearest to with: beos, orson, stayed, stockholders, atrocities, vagueness, hijack, viral,
# Nearest to d: spirits, travis, painted, tequila, witnesses, novelty, chaucer, cyanobacteria,
# Nearest to he: symptom, irrelevent, beechcraft, associated, stranded, medley, ores, clc,
# Average loss at step 2000: 4.367113
# Average loss at step 4000: 3.861425
# Average loss at step 6000: 3.791149
# Average loss at step 8000: 3.692051
# Average loss at step 10000: 3.616196
# Nearest to an: the, inferred, shoots, considerably, exploitative, cga, rotate, flaherty,
# Nearest to some: many, other, caledonians, undo, hype, anthropic, jal, million,
# Nearest to a: the, defiant, data, this, snapper, macdonald, tours, erm,
# Nearest to see: judges, but, cleartype, bouncing, lifetimes, strikes, epitome, antebellum,
# Nearest to used: itself, scilly, conferencing, syllabaries, ladefoged, lamar, pacemaker, produced,
# Nearest to were: are, was, have, although, aground, be, had, engineered,
# Nearest to is: was, are, has, be, racially, accidently, hemi, lobbyist,
# Nearest to if: torsional, attractions, lh, chaney, states, gov, algorithmic, kolbin,
# Nearest to history: braxton, boasted, manchu, raids, jacobi, pagan, ota, misinterpretation,
# Nearest to at: on, by, in, during, bilbao, following, rio, valuables,
# Nearest to can: may, would, must, hizballah, viscous, covens, enclosures, stickball,
# Nearest to which: that, also, this, it, magnetosphere, ionospheric, who, and,
# Nearest to as: saga, hemi, africana, compressible, weekly, unload, murders, erika,
# Nearest to with: by, orson, encampments, for, wither, in, ellesmere, contrasted,
# Nearest to d: b, travis, tequila, antiprotons, and, spirits, chaucer, painted,
# Nearest to he: it, they, who, she, voltages, heaven, there, misled,
# Average loss at step 12000: 3.606981
# Average loss at step 14000: 3.571866
# Average loss at step 16000: 3.408640
# Average loss at step 18000: 3.452538
# Average loss at step 20000: 3.539080
# Nearest to an: inferred, the, shoots, localized, rotate, ht, robins, incorporate,
# Nearest to some: many, these, other, several, caledonians, those, most, lighting,
# Nearest to a: any, snapper, data, this, crumbling, the, macdonald, guitar,
# Nearest to see: cleartype, lifetimes, centrist, stickball, but, nokia, dass, wasp,
# Nearest to used: known, found, produced, conferencing, lamar, anthropology, scilly, exposes,
# Nearest to were: are, was, have, had, although, is, be, burnley,
# Nearest to is: was, are, has, soteriology, were, does, but, jabberwocky,
# Nearest to if: though, when, algorithmic, although, is, torsional, took, symbolise,
# Nearest to history: braxton, manchu, version, unpublished, jacobi, pagan, raids, aesthetically,
# Nearest to at: in, on, during, and, divisive, handkerchief, from, around,
# Nearest to can: may, would, could, must, should, will, might, cannot,
# Nearest to which: that, this, also, it, but, who, omotic, succeeds,
# Nearest to as: saga, via, hemi, tenji, best, mississippian, murders, weigh,
# Nearest to with: orson, encampments, in, by, wither, for, between, at,
# Nearest to d: b, travis, utilize, praline, chaucer, hispanics, stadler, terraced,
# Nearest to he: it, they, she, who, there, voltages, heaven, never,
# Average loss at step 22000: 3.503996
# Average loss at step 24000: 3.488449
# Average loss at step 26000: 3.479904
# Average loss at step 28000: 3.482963
# Average loss at step 30000: 3.505130
# Nearest to an: inferred, shoots, pokemon, barbiturates, considerably, cosmologies, localized, superclass,
# Nearest to some: many, these, several, all, other, petit, most, the,
# Nearest to a: any, the, snapper, molina, interceptions, no, his, this,
# Nearest to see: but, centrist, cleartype, lifetimes, basque, hy, wasp, jal,
# Nearest to used: known, found, produced, referred, written, syllabaries, given, lamar,
# Nearest to were: are, was, have, had, is, although, while, by,
# Nearest to is: was, has, are, does, became, installation, be, were,
# Nearest to if: when, though, although, but, lillee, algorithmic, before, is,
# Nearest to history: braxton, modems, pigot, raids, list, macedon, agamemnon, manchu,
# Nearest to at: during, in, on, near, handkerchief, valuables, rio, rescinded,
# Nearest to can: may, would, could, will, must, should, might, cannot,
# Nearest to which: this, that, it, these, who, mercer, what, but,
# Nearest to as: like, compressible, zara, sagas, with, or, lieutenants, anhalt,
# Nearest to with: between, for, orson, in, among, when, encampments, by,
# Nearest to d: b, chaucer, swung, stadler, praline, reconquista, zealous, hispanics,
# Nearest to he: it, she, they, who, there, but, voltages, shipyard,
# Average loss at step 32000: 3.500684
# Average loss at step 34000: 3.499137
# Average loss at step 36000: 3.454328
# Average loss at step 38000: 3.301501
# Average loss at step 40000: 3.426686
# Nearest to an: shoots, inferred, pokemon, considerably, tagline, hackett, another, robins,
# Nearest to some: many, these, several, any, those, this, their, seats,
# Nearest to a: the, erm, any, cyberpunk, another, progs, kirchenmusik, or,
# Nearest to see: but, lifetimes, jal, centrist, deepened, cleartype, list, wasp,
# Nearest to used: known, found, referred, produced, seen, given, available, interpreted,
# Nearest to were: are, have, was, had, while, these, although, be,
# Nearest to is: was, has, are, if, be, does, while, for,
# Nearest to if: when, is, though, although, for, where, that, bent,
# Nearest to history: ministry, manchu, pigot, braxton, beneficiaries, macedon, status, tragic,
# Nearest to at: during, near, on, in, boutique, valuables, fibreglass, thursdays,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to which: that, this, also, who, it, what, these, but,
# Nearest to as: loved, usr, be, otherwise, is, administrators, lieutenants, hurled,
# Nearest to with: between, when, options, in, by, encampments, among, orson,
# Nearest to d: b, praline, travis, chaucer, utilize, c, decins, swung,
# Nearest to he: she, it, they, who, there, i, originally, voltages,
# Average loss at step 42000: 3.439260
# Average loss at step 44000: 3.452872
# Average loss at step 46000: 3.446960
# Average loss at step 48000: 3.357686
# Average loss at step 50000: 3.385308
# Nearest to an: inferred, shoots, huston, another, needles, cga, hydroxide, ht,
# Nearest to some: many, these, several, both, any, those, most, various,
# Nearest to a: the, another, unwavering, any, evaporation, macdonald, no, stallion,
# Nearest to see: list, deepened, padma, lifetimes, superboy, centrist, alexis, wasp,
# Nearest to used: known, referred, produced, seen, written, given, found, available,
# Nearest to were: are, have, was, be, had, although, is, those,
# Nearest to is: was, are, has, be, were, breastfeeding, indistinguishable, became,
# Nearest to if: when, though, although, where, before, while, since, but,
# Nearest to history: exquisite, beneficiaries, ministry, tragic, see, pigot, hoe, summer,
# Nearest to at: during, on, near, in, forseti, under, rescinded, handkerchief,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to which: this, that, also, who, often, now, what, it,
# Nearest to as: lieutenants, storied, by, formative, anhalt, taiwanese, zara, landmark,
# Nearest to with: between, wither, options, by, encampments, aces, orson, modulated,
# Nearest to d: b, meditator, r, c, stagnant, chaucer, painted, decins,
# Nearest to he: she, it, they, who, there, voltages, i, this,
# Average loss at step 52000: 3.437756
# Average loss at step 54000: 3.426622
# Average loss at step 56000: 3.438410
# Average loss at step 58000: 3.400249
# Average loss at step 60000: 3.393941
# Nearest to an: tagline, considerably, needles, inferred, offender, shoots, the, statistically,
# Nearest to some: many, these, several, any, those, all, the, most,
# Nearest to a: the, any, another, every, beckwith, brooker, unwavering, stallion,
# Nearest to see: list, but, wasp, include, deepened, centrist, references, formalised,
# Nearest to used: known, seen, written, referred, found, interpreted, available, described,
# Nearest to were: are, was, although, have, had, while, those, be,
# Nearest to is: was, has, are, does, although, becomes, be, remains,
# Nearest to if: when, though, although, where, before, since, because, while,
# Nearest to history: demographics, pursuit, ministry, articles, period, status, tragic, inpatient,
# Nearest to at: during, in, forseti, within, under, rescinded, handkerchief, shalom,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to which: that, this, what, it, however, but, also, who,
# Nearest to as: when, olden, like, taiwanese, benedictine, loved, hatta, lutetium,
# Nearest to with: between, when, modulated, encampments, among, ag, ellesmere, hyphae,
# Nearest to d: b, c, j, heartland, midwife, travis, praline, gerardo,
# Nearest to he: she, it, they, there, who, yeltsin, originally, previously,
# Average loss at step 62000: 3.240882
# Average loss at step 64000: 3.252855
# Average loss at step 66000: 3.408408
# Average loss at step 68000: 3.395290
# Average loss at step 70000: 3.360746
# Nearest to an: shoots, huston, needles, inferred, mangaverse, distinguished, offender, another,
# Nearest to some: many, several, these, all, those, certain, the, any,
# Nearest to a: the, another, any, enough, unwavering, tubulin, supercharged, datatypes,
# Nearest to see: list, formalised, include, but, gel, rotten, xiith, including,
# Nearest to used: known, seen, referred, found, available, written, described, produced,
# Nearest to were: are, was, have, had, be, while, although, been,
# Nearest to is: was, has, are, be, becomes, does, lobbyist, although,
# Nearest to if: when, though, although, while, where, before, because, but,
# Nearest to history: ministry, macedon, list, status, salvation, period, backers, pursuit,
# Nearest to at: during, in, shalom, within, forseti, near, rescinded, on,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to which: that, this, but, also, what, however, it, still,
# Nearest to as: when, like, storied, castell, zara, compressible, loved, southerly,
# Nearest to with: between, encampments, when, among, in, options, hyphae, gov,
# Nearest to d: b, h, n, r, j, travis, praline, scheer,
# Nearest to he: she, it, they, who, there, yeltsin, then, gere,
# Average loss at step 72000: 3.373018
# Average loss at step 74000: 3.347825
# Average loss at step 76000: 3.315817
# Average loss at step 78000: 3.351243
# Average loss at step 80000: 3.377209
# Nearest to an: inferred, shoots, another, offender, huston, tagline, leaguers, mangaverse,
# Nearest to some: many, several, these, most, any, all, certain, various,
# Nearest to a: another, the, macdonald, tubulin, snapper, unwavering, kalmar, every,
# Nearest to see: include, but, list, references, lifetimes, gel, formalised, including,
# Nearest to used: known, referred, seen, written, available, found, described, produced,
# Nearest to were: are, was, had, have, those, although, been, became,
# Nearest to is: was, has, are, soteriology, piccard, becomes, became, jabberwocky,
# Nearest to if: when, though, before, since, where, because, should, although,
# Nearest to history: macedon, salvation, ministry, exquisite, manufacturing, list, backers, boer,
# Nearest to at: during, in, shalom, forseti, rescinded, fibreglass, on, handkerchief,
# Nearest to can: could, may, will, would, should, must, cannot, might,
# Nearest to which: that, this, also, who, still, but, what, it,
# Nearest to as: anhalt, when, salem, prosody, willy, betraying, africana, inclinations,
# Nearest to with: among, between, when, wither, hyphae, options, encampments, gov,
# Nearest to d: b, scheer, c, h, j, crayfish, travis, inlet,
# Nearest to he: she, it, they, there, who, we, yeltsin, soon,
# Average loss at step 82000: 3.405597
# Average loss at step 84000: 3.411432
# Average loss at step 86000: 3.388517
# Average loss at step 88000: 3.360289
# Average loss at step 90000: 3.365873
# Nearest to an: huston, inferred, shoots, flashing, earners, another, cga, tagline,
# Nearest to some: many, several, these, all, most, certain, any, this,
# Nearest to a: any, the, hamas, enough, another, macdonald, interceptions, unwavering,
# Nearest to see: include, list, references, external, gel, but, formalised, rotten,
# Nearest to used: known, seen, referred, produced, available, applied, designed, found,
# Nearest to were: are, had, was, although, while, have, those, these,
# Nearest to is: was, has, are, dials, jabberwocky, makes, although, becomes,
# Nearest to if: when, where, though, since, although, before, should, after,
# Nearest to history: macedon, list, summary, ministry, salvation, manufacturing, herculaneum, hoe,
# Nearest to at: during, near, in, under, extremism, snk, without, within,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to which: that, this, also, what, who, it, actually, but,
# Nearest to as: predate, zara, via, olden, anhalt, laozi, salem, handkerchief,
# Nearest to with: between, by, in, from, encampments, wither, when, modulated,
# Nearest to d: b, tequila, scheer, zealous, retrieved, leonov, travis, solute,
# Nearest to he: she, it, they, there, who, but, originally, later,
# Average loss at step 92000: 3.400075
# Average loss at step 94000: 3.260394
# Average loss at step 96000: 3.356864
# Average loss at step 98000: 3.242842
# Average loss at step 100000: 3.355127
# Nearest to an: another, inferred, huston, cga, ius, tagline, flashing, shoots,
# Nearest to some: many, several, these, any, certain, all, various, those,
# Nearest to a: another, the, unwavering, any, arson, enough, snapper, prismatic,
# Nearest to see: references, list, external, include, includes, formalised, links, refer,
# Nearest to used: seen, known, applied, available, found, designed, sold, referred,
# Nearest to were: are, was, had, have, those, these, although, sheaf,
# Nearest to is: was, has, became, be, becomes, are, seems, jabberwocky,
# Nearest to if: when, though, where, because, before, since, although, should,
# Nearest to history: list, summary, manufacturing, selection, macedon, description, asphyxia, carla,
# Nearest to at: during, in, valuables, divisive, on, near, handkerchief, chipmunks,
# Nearest to can: could, may, will, must, would, cannot, should, might,
# Nearest to which: that, this, what, however, these, actually, but, usually,
# Nearest to as: like, how, before, screens, castell, zara, when, compressible,
# Nearest to with: between, aces, modulated, including, in, orson, trump, stoppage,
# Nearest to d: b, caravans, zealous, c, h, crispy, liliales, matt,
# Nearest to he: she, they, it, there, we, who, quad, soon,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, 2 * bag_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  window = collections.deque(maxlen=span) # sliding window
  for _ in range(span):
    window.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = bag_window  # target label at the center of the window
    buffer = list(window)
    labels[i, 0] = buffer.pop(target)
    batch[i] = buffer
    window.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[x] for x in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed_sum = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), axis=1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed_sum,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.981485
# Nearest to will: chogm, luncheon, juice, czes, bigcup, centaurus, germania, behavior,
# Nearest to th: alters, statistician, timepieces, burma, bum, glenda, sauron, newport,
# Nearest to he: schuman, unhelpful, counterproductive, nbs, ladoga, exeter, austrasia, hera,
# Nearest to that: damp, intake, ams, tumultuous, jsf, allegro, pick, safest,
# Nearest to system: nightclubs, flavors, alga, garc, deficiencies, denmark, crime, stripes,
# Nearest to five: hanseatic, scotland, rasterization, monies, equation, dukakis, alleles, ffffff,
# Nearest to are: sardaukar, noses, embody, orphan, jamo, mikhail, noting, chokes,
# Nearest to with: contend, communicative, represent, editor, uniformitarianism, superficially, bullock, leung,
# Nearest to three: seagull, cker, kilimanjaro, record, entrusted, batting, hunter, look,
# Nearest to new: kaist, yeah, door, taney, leigh, mineralogical, vecchio, meet,
# Nearest to often: saltwater, inquiring, tumbling, jewishencyclopedia, lictors, hedge, hideo, todd,
# Nearest to war: bailiwick, hadadezer, assam, traits, ironclad, cruijff, hayt, vulnerabilities,
# Nearest to to: christina, cisneros, render, ssn, result, petn, nes, tyrol,
# Nearest to united: crony, surmounted, pamphlet, disbandment, harlan, rr, dramatic, nonetheless,
# Nearest to world: crewmembers, genetic, ruth, kling, babel, asphyxiation, pam, jvm,
# Nearest to other: shay, copulation, upwelling, narrow, institutions, walla, mt, syncopated,
# Average loss at step 2000: 4.568469
# Average loss at step 4000: 3.929072
# Average loss at step 6000: 3.712340
# Average loss at step 8000: 3.538637
# Average loss at step 10000: 3.478243
# Nearest to will: would, may, could, can, should, cannot, to, must,
# Nearest to th: persecuted, szl, pogrom, gumby, painterly, joy, bathe, coldcut,
# Nearest to he: it, she, who, they, insensitivity, herzl, unfamiliar, audiogalaxy,
# Nearest to that: which, aryabhata, who, aboriginals, when, sibm, where, appoint,
# Nearest to system: capability, nightclubs, michinaga, conservatory, iia, cylinder, meteorologist, deficiencies,
# Nearest to five: eight, four, six, three, seven, zero, nine, two,
# Nearest to are: were, is, was, gillies, blink, mets, ellery, sticky,
# Nearest to with: and, for, peerages, during, of, quintessence, ashton, foyle,
# Nearest to three: six, five, four, seven, eight, zero, two, nine,
# Nearest to new: ballpoint, pk, ox, overdoses, ranch, particularity, chrome, reflux,
# Nearest to often: sometimes, entrepreneurs, underwood, minigun, louisa, commonly, denote, fitna,
# Nearest to war: derailleur, wideband, golems, warfield, retcon, strafford, traits, admitted,
# Nearest to to: would, will, may, could, must, can, should, mesoplodon,
# Nearest to united: pamphlet, litter, rem, cowan, disbandment, suleiman, crony, cleveland,
# Nearest to world: phnom, altitude, efforts, docile, phocas, cab, raced, flourished,
# Nearest to other: these, many, different, both, various, some, relevant, ulrike,
# Average loss at step 12000: 3.481137
# Average loss at step 14000: 3.437316
# Average loss at step 16000: 3.434752
# Average loss at step 18000: 3.401531
# Average loss at step 20000: 3.220905
# Nearest to will: would, could, should, can, may, cannot, must, might,
# Nearest to th: st, nd, nine, predictable, persecuted, doubling, evaporative, vide,
# Nearest to he: she, it, they, who, herzl, buggy, wanders, levite,
# Nearest to that: which, where, this, what, when, however, who, satisfiability,
# Nearest to system: systems, meteorologist, vagaries, tofu, iia, malfunctions, conservatory, regina,
# Nearest to five: seven, six, three, eight, zero, four, nine, two,
# Nearest to are: were, is, include, have, blink, was, can, be,
# Nearest to with: between, usps, using, including, for, and, stratton, unlocked,
# Nearest to three: seven, five, six, eight, four, two, nine, zero,
# Nearest to new: ballpoint, ox, minimalism, bentine, interwoven, hangover, tended, curve,
# Nearest to often: usually, commonly, generally, sometimes, also, now, underwood, still,
# Nearest to war: consonantal, retcon, wideband, punctuation, lobbying, derailleur, strafford, blend,
# Nearest to to: will, may, could, can, would, might, should, must,
# Nearest to united: litter, villages, ligament, suleiman, thanksgiving, pamphlet, barnabas, rem,
# Nearest to world: cheltenham, centuries, league, borderlands, treviso, cab, industry, noi,
# Nearest to other: various, some, different, these, those, more, superseding, untso,
# Average loss at step 22000: 3.360702
# Average loss at step 24000: 3.289296
# Average loss at step 26000: 3.258452
# Average loss at step 28000: 3.287828
# Average loss at step 30000: 3.227912
# Nearest to will: could, would, can, should, may, must, might, cannot,
# Nearest to th: st, nine, nd, predictable, saumur, rd, equation, five,
# Nearest to he: she, it, they, urbe, watering, never, arnhem, be,
# Nearest to that: which, where, who, satisfiability, however, this, aryabhata, what,
# Nearest to system: systems, conservatory, program, sporty, device, concept, code, rz,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to are: were, is, include, was, blink, have, unbroken, takeovers,
# Nearest to with: between, mcnally, sponsor, goodness, daddy, gives, kur, dimethyl,
# Nearest to three: four, eight, five, six, seven, two, nine, pp,
# Nearest to new: ballpoint, frazer, spurring, minimalism, mitford, combination, jenny, directx,
# Nearest to often: sometimes, commonly, usually, generally, widely, now, still, also,
# Nearest to war: consonantal, derailleur, diagnoses, retcon, zhao, blend, arrival, wimbledon,
# Nearest to to: would, will, must, could, should, may, endeavored, might,
# Nearest to united: alabama, thanksgiving, japan, placid, steno, auden, batter, villages,
# Nearest to world: bhumi, tesco, scared, trojan, cemeteries, treviso, tgv, retailer,
# Nearest to other: various, those, different, these, others, intercalary, mcfadden, many,
# Average loss at step 32000: 3.011398
# Average loss at step 34000: 3.199987
# Average loss at step 36000: 3.193888
# Average loss at step 38000: 3.161692
# Average loss at step 40000: 3.162575
# Nearest to will: would, could, should, must, may, can, cannot, might,
# Nearest to th: st, nd, nine, twentieth, rd, eight, analogs, failing,
# Nearest to he: she, it, they, never, landmine, audiogalaxy, communists, arnhem,
# Nearest to that: which, although, however, where, furniture, xxviii, understands, what,
# Nearest to system: systems, process, program, prisms, conservatory, service, habitation, astounding,
# Nearest to five: six, eight, four, seven, nine, zero, three, two,
# Nearest to are: were, is, was, include, mets, have, being, limp,
# Nearest to with: between, dame, within, busing, using, without, cosmonauts, by,
# Nearest to three: six, eight, four, seven, five, two, zero, nine,
# Nearest to new: mitford, ballpoint, certain, magnetization, telegraphy, thai, ptl, fuelled,
# Nearest to often: usually, sometimes, commonly, generally, widely, still, frequently, typically,
# Nearest to war: consonantal, wars, zhao, diagnoses, derailleur, retcon, happiest, wolff,
# Nearest to to: would, may, will, should, must, might, can, cannot,
# Nearest to united: us, thanksgiving, alabama, japanese, highest, northeast, auden, punjab,
# Nearest to world: trojan, kosovo, industry, scared, qq, wirth, harassment, bhumi,
# Nearest to other: various, popper, older, others, their, cedilla, obscurity, different,
# Average loss at step 42000: 3.213424
# Average loss at step 44000: 3.135286
# Average loss at step 46000: 3.144848
# Average loss at step 48000: 3.055528
# Average loss at step 50000: 3.051626
# Nearest to will: would, could, may, must, should, can, might, cannot,
# Nearest to th: nd, nine, twentieth, st, rd, analogs, nineteenth, saumur,
# Nearest to he: she, it, they, audiogalaxy, whitespace, cronenberg, subculture, watering,
# Nearest to that: which, although, what, where, starved, however, aryabhata, dizzy,
# Nearest to system: systems, process, program, iia, thalberg, aisha, photosensitive, conservatory,
# Nearest to five: six, seven, four, three, eight, zero, two, nine,
# Nearest to are: were, is, was, include, have, being, ulrike, contain,
# Nearest to with: between, dame, daddy, gives, hazel, cbs, mcnally, using,
# Nearest to three: four, six, five, seven, eight, two, zero, nine,
# Nearest to new: mitford, distinct, particular, ballpoint, telegraphy, magnetization, special, certain,
# Nearest to often: usually, commonly, generally, sometimes, still, widely, frequently, typically,
# Nearest to war: wars, consonantal, diagnoses, arrival, zhao, communism, zr, amphetamines,
# Nearest to to: will, can, could, must, cannot, should, might, would,
# Nearest to united: thanksgiving, collectivized, elites, highest, us, alabama, commonwealth, stationery,
# Nearest to world: bhumi, partials, cemeteries, trojan, industry, clan, roasting, mnemonics,
# Nearest to other: various, older, rather, different, smaller, condom, others, fewer,
# Average loss at step 52000: 3.094621
# Average loss at step 54000: 3.088260
# Average loss at step 56000: 2.924595
# Average loss at step 58000: 3.021120
# Average loss at step 60000: 3.051977
# Nearest to will: would, could, should, might, may, must, can, cannot,
# Nearest to th: nd, twentieth, st, rd, eighteenth, second, nine, nineteenth,
# Nearest to he: she, it, they, who, landmine, slugging, ulcers, audiogalaxy,
# Nearest to that: which, however, where, humiliation, when, avc, starved, what,
# Nearest to system: systems, process, component, bid, conservatory, company, citeseer, sporty,
# Nearest to five: eight, seven, six, four, three, nine, zero, two,
# Nearest to are: were, is, was, include, including, exist, blink, exists,
# Nearest to with: between, gives, stained, dimethyl, via, cbs, conservatorio, sahih,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to new: inkjet, soups, magnetization, mitford, distinct, ballpoint, chadic, mwi,
# Nearest to often: usually, commonly, generally, sometimes, widely, frequently, typically, still,
# Nearest to war: wars, consonantal, arrival, communism, diagnoses, gniezno, jb, modeling,
# Nearest to to: could, would, will, cannot, mirabeau, might, must, shall,
# Nearest to united: member, widest, alabama, commonwealth, us, archimedes, elites, molino,
# Nearest to world: orbit, realm, hafez, am, bhumi, overlapped, silvery, strongest,
# Nearest to other: various, smaller, older, numerous, rather, fewer, larger, different,
# Average loss at step 62000: 3.011682
# Average loss at step 64000: 2.922532
# Average loss at step 66000: 2.932242
# Average loss at step 68000: 2.967093
# Average loss at step 70000: 3.006675
# Nearest to will: must, can, could, should, might, would, may, cannot,
# Nearest to th: nd, twentieth, nine, st, eighteenth, nineteenth, rd, next,
# Nearest to he: she, it, who, they, whitespace, audiogalaxy, distributist, hydroponics,
# Nearest to that: which, humiliation, but, where, however, although, because, dizzy,
# Nearest to system: systems, process, program, pipe, inhabits, conservatory, vagaries, modes,
# Nearest to five: seven, six, three, four, zero, eight, two, missoula,
# Nearest to are: were, is, include, exist, was, including, contain, enjoys,
# Nearest to with: between, gives, dame, malawi, busing, carr, hazel, when,
# Nearest to three: five, six, seven, two, four, zero, eight, topaz,
# Nearest to new: mitford, different, ballpoint, separate, soups, special, magnetization, inkjet,
# Nearest to often: commonly, sometimes, frequently, usually, generally, widely, typically, now,
# Nearest to war: wars, consonantal, arrival, season, diagnoses, jb, communism, warfield,
# Nearest to to: must, will, endeavored, might, mirabeau, cannot, could, should,
# Nearest to united: widest, us, commonwealth, molino, steno, wheelbase, confederate, archimedes,
# Nearest to world: u, orbit, bhumi, sous, decrees, improvement, matches, overlapped,
# Nearest to other: various, fewer, different, older, smaller, individual, rather, others,
# Average loss at step 72000: 2.940768
# Average loss at step 74000: 2.874789
# Average loss at step 76000: 2.998215
# Average loss at step 78000: 3.007610
# Average loss at step 80000: 2.846777
# Nearest to will: would, could, must, should, might, can, may, cannot,
# Nearest to th: nd, st, twentieth, nine, nineteenth, eighteenth, rd, eight,
# Nearest to he: she, it, they, whitespace, who, audiogalaxy, there, rethinking,
# Nearest to that: which, humiliation, where, however, unless, what, who, furniture,
# Nearest to system: systems, process, conservatory, program, bid, summary, sweetened, vagaries,
# Nearest to five: four, seven, six, three, eight, zero, nine, two,
# Nearest to are: were, is, include, have, contain, was, exist, takeovers,
# Nearest to with: between, gives, quintessence, dame, via, mannerisms, among, without,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to new: local, mitford, inkjet, separate, certain, special, frazer, different,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, widely, now,
# Nearest to war: wars, consonantal, diagnoses, conflict, arrival, communism, week, strafford,
# Nearest to to: will, might, must, would, may, could, endeavored, should,
# Nearest to united: steno, widest, collectivized, commonwealth, brin, confederate, alabama, synthase,
# Nearest to world: u, matches, country, overlapped, treviso, orbit, fuselage, cheltenham,
# Nearest to other: various, fewer, these, intercalary, others, both, bowers, their,
# Average loss at step 82000: 2.931340
# Average loss at step 84000: 2.901087
# Average loss at step 86000: 2.922547
# Average loss at step 88000: 2.945706
# Average loss at step 90000: 2.831223
# Nearest to will: would, should, must, can, could, might, may, cannot,
# Nearest to th: twentieth, st, nd, nineteenth, eighteenth, nine, next, third,
# Nearest to he: she, it, they, barely, levite, chalmers, expos, company,
# Nearest to that: which, when, where, what, humiliation, actually, durango, wailing,
# Nearest to system: systems, network, process, virulent, sweetened, spline, program, company,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to are: were, is, include, was, contain, exist, represent, frideric,
# Nearest to with: between, dame, via, gives, using, charming, against, nou,
# Nearest to three: four, six, five, eight, seven, two, zero, nine,
# Nearest to new: separate, ballpoint, special, local, distinct, mitford, certain, warner,
# Nearest to often: sometimes, generally, usually, frequently, commonly, typically, occasionally, rarely,
# Nearest to war: consonantal, wars, conflict, warfield, jb, diagnoses, arrival, season,
# Nearest to to: will, must, might, could, towards, would, cannot, can,
# Nearest to united: us, widest, flagellates, commonwealth, steno, punjab, wheelbase, raskin,
# Nearest to world: country, overlapped, u, reality, universe, punic, interests, orbit,
# Nearest to other: fewer, others, various, different, superseding, older, earlier, certain,
# Average loss at step 92000: 2.901244
# Average loss at step 94000: 2.881721
# Average loss at step 96000: 2.708668
# Average loss at step 98000: 2.459456
# Average loss at step 100000: 2.713604
# Nearest to will: should, would, could, can, must, might, shall, may,
# Nearest to th: nd, twentieth, st, nineteenth, seventh, eighteenth, rd, nine,
# Nearest to he: she, it, they, chalmers, who, whitespace, esas, astrology,
# Nearest to that: which, where, however, although, wailing, starved, humiliation, whom,
# Nearest to system: systems, conservatory, process, vagaries, thalberg, style, modes, model,
# Nearest to five: six, four, three, seven, eight, zero, nine, two,
# Nearest to are: were, is, was, include, exist, contain, have, remain,
# Nearest to with: between, besides, gives, among, quintessence, dimethyl, via, dame,
# Nearest to three: four, five, seven, six, eight, two, zero, nine,
# Nearest to new: old, ballpoint, inkjet, mitford, florentines, warner, spurring, distinct,
# Nearest to often: sometimes, frequently, generally, usually, typically, commonly, occasionally, also,
# Nearest to war: wars, consonantal, conflict, revolution, liberties, ghost, ridicule, jb,
# Nearest to to: might, towards, will, must, would, could, can, cannot,
# Nearest to united: confederate, us, flagellates, steno, fab, collectivized, rubenstein, commonwealth,
# Nearest to world: u, overlapped, nation, trojan, orbit, perishable, phenomenon, matches,
# Nearest to other: others, various, different, earlier, both, fewer, these, mcfadden,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
